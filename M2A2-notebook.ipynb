# %%
import pandas as pd

# %%
dados_populacao = pd.read_csv('populacao.csv')

# %%
print(type(dados_populacao))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dados_populacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ranking    319 non-null    int64
#  1   municipio  319 non-null    object
#  2   uf         319 non-null    object
#  3   populacao  319 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 10.1+ KB

# %%
dados_populacao.head(10)
# Out:
#    ranking       municipio                uf  populacao
# 0        1       São Paulo         São Paulo   11451999
# 1        2  Rio de Janeiro    Rio de Janeiro    6211223
# 2        3        Brasília  Distrito Federal    2817381
# 3        4       Fortaleza             Ceará    2428708
# 4        5        Salvador             Bahia    2417678
# 5        6  Belo Horizonte      Minas Gerais    2315560
# 6        7          Manaus          Amazonas    2063689
# 7        8        Curitiba            Paraná    1773718
# 8        9          Recife        Pernambuco    1488920
# 9       10         Goiânia             Goiás    1437366

# %%
dados_populacao.tail()
# Out:
#      ranking   municipio              uf  populacao
# 314      315  Manacapuru        Amazonas     101883
# 315      316      Balsas        Maranhão     101767
# 316      317     Lagarto         Sergipe     101579
# 317      318       Assis       São Paulo     101409
# 318      319   Itaperuna  Rio de Janeiro     101041

# %% [markdown]
# # Colunas

# %%
dados_populacao['municipio']
# Out:
# 0           São Paulo
# 1      Rio de Janeiro
# 2            Brasília
# 3           Fortaleza
# 4            Salvador
#             ...
# 314        Manacapuru
# 315            Balsas
# 316           Lagarto
# 317             Assis
# 318         Itaperuna
# Name: municipio, Length: 319, dtype: object

# %%
dados_populacao[['municipio', 'uf']]
# Out:
#           municipio                uf
# 0         São Paulo         São Paulo
# 1    Rio de Janeiro    Rio de Janeiro
# 2          Brasília  Distrito Federal
# 3         Fortaleza             Ceará
# 4          Salvador             Bahia
# ..              ...               ...
# 314      Manacapuru          Amazonas
# 315          Balsas          Maranhão
# 316         Lagarto           Sergipe
# 317           Assis         São Paulo
# 318       Itaperuna    Rio de Janeiro
#
# [319 rows x 2 columns]

# %% [markdown]
# # Valores Específicos

# %%
dados_populacao.iloc[9]
# Out:
# ranking           10
# municipio    Goiânia
# uf             Goiás
# populacao    1437366
# Name: 9, dtype: object

# %%
dados_populacao.iloc[10:20]
# Out:
#     ranking     municipio                  uf  populacao
# 10       11  Porto Alegre   Rio Grande do Sul    1332845
# 11       12         Belém                Pará    1303403
# 12       13     Guarulhos           São Paulo    1291771
# 13       14      Campinas           São Paulo    1139047
# 14       15      São Luís            Maranhão    1037775
# 15       16        Maceió             Alagoas     957916
# 16       17  Campo Grande  Mato Grosso do Sul     898100
# 17       18   São Gonçalo      Rio de Janeiro     896744
# 18       19      Teresina               Piauí     866300
# 19       20   João Pessoa             Paraíba     833932

# %%
dados_populacao[dados_populacao['ranking'] == 10]
# Out:
#    ranking municipio     uf  populacao
# 9       10   Goiânia  Goiás    1437366

# %%
dados_populacao[dados_populacao['uf'] == 'Rio Grande do Sul']
# Out:
#      ranking          municipio                 uf  populacao
# 10        11       Porto Alegre  Rio Grande do Sul    1332845
# 47        48      Caxias do Sul  Rio Grande do Sul     463501
# 78        79             Canoas  Rio Grande do Sul     347657
# 85        86            Pelotas  Rio Grande do Sul     325685
# 37      217           Campo Largo             Paraná     136327
# 38      218          Cachoeirinha  Rio Grande do Sul     136258
# 39      224     Santa Cruz do Sul  Rio Grande do Sul     133230
# 40      226       Sapucaia do Sul  Rio Grande do Sul     132107
# 41      231             Apucarana             Paraná     130134
# 42      237               Pinhais             Paraná     127019
# 43      248       Bento Gonçalves  Rio Grande do Sul     123151
# 44      253   Almirante Tamandaré             Paraná     119825
# 45      254             Arapongas             Paraná     119138
# 46      256             Piraquara             Paraná     118730
# 47      257               Sarandi             Paraná     118455
# 48      260                  Bagé  Rio Grande do Sul     117938
# 49      262            Uruguaiana  Rio Grande do Sul     117210
# 50      263              Umuarama             Paraná     117095
# 51      286               Tubarão     Santa Catarina     110088
# 52      290                 Cambé             Paraná     107208
# 53      295               Erechim  Rio Grande do Sul     105705
# 54      312              Camboriú     Santa Catarina     103074

# %%
dados_populacao_sul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ranking    55 non-null     int64
#  1   municipio  55 non-null     object
#  2   uf         55 non-null     object
#  3   populacao  55 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.8+ KB

# %%
dados_populacao_sul[dados_populacao_sul['populacao'] >= 250000]
# Out:
#     ranking             municipio                 uf  populacao
# 0         8              Curitiba             Paraná    1773718
# 1        11          Porto Alegre  Rio Grande do Sul    1332845
# 2        34             Joinville     Santa Catarina     616317
# 3        37              Londrina             Paraná     555965
# 4        39         Florianópolis     Santa Catarina     537211
# 5        48         Caxias do Sul  Rio Grande do Sul     463501
# 6        61               Maringá             Paraná     409657
# 7        71              Blumenau     Santa Catarina     361261
# 8        72          Ponta Grossa             Paraná     358371
# 9        78              Cascavel             Paraná     348051
# 10       79                Canoas  Rio Grande do Sul     347657
# 11       85  São José dos Pinhais             Paraná     329628
# 12       86               Pelotas  Rio Grande do Sul     325685
# 13       97         Foz do Iguaçu             Paraná     285415
# 14      103           Santa Maria  Rio Grande do Sul     271735
# 15      104              São José     Santa Catarina     270299
# 16      107              Gravataí  Rio Grande do Sul     265074
# 17      109                Itajaí     Santa Catarina     264054
# 18      114               Chapecó     Santa Catarina     254785

# %%
dados_populacao[dados_populacao['uf'].isin(regiao_sul) & (dados_populacao['populacao'] >= 250000)]
# Out:
#      ranking             municipio                 uf  populacao
# 7          8              Curitiba             Paraná    1773718
# 10        11          Porto Alegre  Rio Grande do Sul    1332845
# 33        34             Joinville     Santa Catarina     616317
# 36        37              Londrina             Paraná     555965
# 38        39         Florianópolis     Santa Catarina     537211
# 47        48         Caxias do Sul  Rio Grande do Sul     463501
# 60        61               Maringá             Paraná     409657
# 70        71              Blumenau     Santa Catarina     361261
# 71        72          Ponta Grossa             Paraná     358371
# 77        78              Cascavel             Paraná     348051
# 78        79                Canoas  Rio Grande do Sul     347657
# 84        85  São José dos Pinhais             Paraná     329628
# 85        86               Pelotas  Rio Grande do Sul     325685
# 96        97         Foz do Iguaçu             Paraná     285415
# 102      103           Santa Maria  Rio Grande do Sul     271735
# 103      104              São José     Santa Catarina     270299
# 106      107              Gravataí  Rio Grande do Sul     265074
# 108      109                Itajaí     Santa Catarina     264054
# 113      114               Chapecó     Santa Catarina     254785

# %% [markdown]
# # Unindo tabelas

# %%
dados_area_urbana = pd.read_csv('area_urbana.csv')

# %%
dados_area_urbana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ranking          955 non-null    int64
#  1   municipio        955 non-null    object
#  2   uf               955 non-null    object
#  3   area urbana km²  955 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 30.0+ KB

# %%
dados_area_urbana.head(10)
# Out:
#    ranking       municipio                  uf  area urbana km²
# 0        1       São Paulo           São Paulo         914.5644
# 1        2  Rio de Janeiro      Rio de Janeiro         640.3365
# 2        3        Brasília    Distrito Federal         590.2166
# 3        4        Curitiba              Paraná         336.5066
# 4        5         Goiânia               Goiás         301.5507
# 5        6          Manaus            Amazonas         277.0854
# 6        7  Belo Horizonte        Minas Gerais         274.0420
# 7        8       Fortaleza               Ceará         253.6912
# 8        9    Campo Grande  Mato Grosso do Sul         252.6269
# 9       10        Campinas           São Paulo         245.1428

# %% [markdown]
# ### Mantendo todos os dados

# %%
 # utilizando o método outer, que une duas tabelas através de dados em comum, mas caso não haja match, ele mantém o dado e preenche com vazio. dessa forma, os dados das duas tabelas são mantidos

dados_populacao_area_urbana = pd.merge(
    left=dados_populacao, right=dados_area_urbana,
    how='outer', on=['municipio', 'uf'],
    suffixes=[' populacao', ' area urbana']
)

# %%
dados_populacao_area_urbana.head(10)
# Out:
#    ranking populacao     municipio                 uf  populacao  \
# 0              190.0    Abaetetuba               Pará   158188.0
# 1                NaN  Abreu e Lima         Pernambuco        NaN
# 2                NaN        Acaraú              Ceará        NaN
# 3                NaN    Adamantina          São Paulo        NaN
# 4                NaN         Agudo  Rio Grande do Sul        NaN
# 5                NaN        Agudos          São Paulo        NaN
# 6              199.0    Alagoinhas              Bahia   151055.0
# 7                NaN      Alegrete  Rio Grande do Sul        NaN
# 8                NaN      Alenquer               Pará        NaN
# 9                NaN      Alexânia              Goiás        NaN
#
#    ranking area urbana  area urbana km²
# 0                336.0          26.1655
# 1                499.0          18.9961
# 2                585.0          16.3326
# 3                769.0          12.4262
# 4                771.0          12.3981
# 5                823.0          11.6345
# 6                228.0          34.6101
# 7                472.0          20.0256
# 8                711.0          13.6116
# 9                445.0          21.0877

# %%
dados_populacao_area_urbana.tail()
# Out:
#      ranking populacao              municipio           uf  populacao  \
# 952                NaN               Xinguara         Pará        NaN
# 953                NaN                Zé Doca     Maranhão        NaN
# 954                NaN               Água Boa  Mato Grosso        NaN
# 955              137.0  Águas Lindas de Goiás        Goiás   225693.0
# 956                NaN                 Óbidos         Pará        NaN
#
#      ranking area urbana  area urbana km²
# 952                584.0          16.3999
# 953                844.0          11.3096
# 954                885.0          10.7856
# 955                158.0          43.8678
# 956                770.0          12.4217

# %%
dados_populacao_area_urbana.isna().sum()
# Out:
# ranking populacao      638
# municipio                0
# uf                       0
# populacao              638
# ranking area urbana      2
# area urbana km²          2
# dtype: int64

# %% [markdown]
# ### Apenas dados em comum nas duas tabelas

# %%
dados_densidade = pd.merge(
    left=dados_populacao, right=dados_area_urbana,
    how='inner', on=['municipio', 'uf'],
    suffixes=[' populacao', ' area urbana']
)

# %%
dados_densidade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ranking populacao    317 non-null    int64
#  1   municipio            317 non-null    object
#  2   uf                   317 non-null    object
#  3   populacao            317 non-null    int64
#  4   ranking area urbana  317 non-null    int64
#  5   area urbana km²      317 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 15.0+ KB

# %%
dados_densidade.head()
# Out:
#    ranking populacao       municipio                uf  populacao  \
# 0                  1       São Paulo         São Paulo   11451999
# 1                  2  Rio de Janeiro    Rio de Janeiro    6211223
# 2                  3        Brasília  Distrito Federal    2817381
# 3                  4       Fortaleza             Ceará    2428708
# 4                  5        Salvador             Bahia    2417678
#
#    ranking area urbana  area urbana km²
# 0                    1         914.5644
# 1                    2         640.3365
# 2                    3         590.2166
# 3                    8         253.6912
# 4                   12         196.2572

# %%
dados_densidade.tail()
# Out:
#      ranking populacao   municipio              uf  populacao  \
# 312                315  Manacapuru        Amazonas     101883
# 313                316      Balsas        Maranhão     101767
# 314                317     Lagarto         Sergipe     101579
# 315                318       Assis       São Paulo     101409
# 316                319   Itaperuna  Rio de Janeiro     101041
#
#      ranking area urbana  area urbana km²
# 312                  630          15.5020
# 313                  324          26.9199
# 314                  314          27.2336
# 315                  320          27.0427
# 316                  478          19.9217

# %% [markdown]
# # Salvando um novo DataFrame

# %%
dados_densidade['habitantes por km²'] = dados_densidade['populacao'] / dados_densidade['area urbana km²']
dados_densidade
# Out:
#      ranking populacao       municipio                uf  populacao  \
# 0                    1       São Paulo         São Paulo   11451999
# 1                    2  Rio de Janeiro    Rio de Janeiro    6211223
# 2                    3        Brasília  Distrito Federal    2817381
# 3                    4       Fortaleza             Ceará    2428708
# 4                    5        Salvador             Bahia    2417678
# ..                 ...             ...               ...        ...
# 312                315      Manacapuru          Amazonas     101883
# 313                316          Balsas          Maranhão     101767
# 314                317         Lagarto           Sergipe     101579
# 315                318           Assis         São Paulo     101409
# 316                319       Itaperuna    Rio de Janeiro     101041
#
#      ranking area urbana  area urbana km²  habitantes por km²
# 0                      1         914.5644        12521.807103
# 1                      2         640.3365         9699.935893
# 2                      3         590.2166         4773.469604
# 3                      8         253.6912         9573.481461
# 4                     12         196.2572        12318.926388
# ..                   ...              ...                 ...
# 312                  630          15.5020         6572.248742
# 313                  324          26.9199         3780.363226
# 314                  314          27.2336         3729.914517
# 315                  320          27.0427         3749.958399
# 316                  478          19.9217         5071.906514
#
# [317 rows x 7 columns]

# %%
# ordenando os valores da coluna 'habitantes por km²' de forma decrescente, zerando os indexes
dados_densidade = dados_densidade.sort_values(by='habitantes por km²', ascending=False).reset_index(drop=True)
dados_densidade
# Out:
#      ranking populacao           municipio              uf  populacao  \
# 0                  101     Taboão da Serra       São Paulo     273542
# 1                   63             Diadema       São Paulo     393237
# 2                   83         São Vicente       São Paulo     329911
# 3                   53  São João de Meriti  Rio de Janeiro     440962
# 4                    1           São Paulo       São Paulo   11451999
# ..                 ...                 ...             ...        ...
# 312                188             Atibaia       São Paulo     158647
# 313                139            Itaboraí  Rio de Janeiro     224267
# 314                251             Itatiba       São Paulo     121590
# 315                154              Maricá  Rio de Janeiro     197277
# 316                232            Araruama  Rio de Janeiro     129671
#
#      ranking area urbana  area urbana km²  habitantes por km²
# 0                    516          18.6092        14699.288524
# 1                    311          27.5114        14293.601925
# 2                    334          26.2317        12576.805926
# 3                    221          35.2135        12522.526872
# 4                      1         914.5644        12521.807103
# ..                   ...              ...                 ...
# 312                  100          64.2782         2468.130719
# 313                   52          92.8138         2416.310937
# 314                  130          52.2255         2328.173019
# 315                   60          85.8766         2297.214841
# 316                   96          64.8404         1999.848860
#
# [317 rows x 7 columns]

# %%
dados_densidade['ranking densidade'] = dados_densidade.index + 1
dados_densidade
# Out:
#      ranking populacao           municipio              uf  populacao  \
# 0                  101     Taboão da Serra       São Paulo     273542
# 1                   63             Diadema       São Paulo     393237
# 2                   83         São Vicente       São Paulo     329911
# 3                   53  São João de Meriti  Rio de Janeiro     440962
# 4                    1           São Paulo       São Paulo   11451999
# ..                 ...                 ...             ...        ...
# 312                188             Atibaia       São Paulo     158647
# 313                139            Itaboraí  Rio de Janeiro     224267
# 314                251             Itatiba       São Paulo     121590
# 315                154              Maricá  Rio de Janeiro     197277
# 316                232            Araruama  Rio de Janeiro     129671
#
#      ranking area urbana  area urbana km²  habitantes por km²  \
# 0                    516          18.6092        14699.288524
# 1                    311          27.5114        14293.601925
# 2                    334          26.2317        12576.805926
# 3                    221          35.2135        12522.526872
# 4                      1         914.5644        12521.807103
# ..                   ...              ...                 ...
# 312                  100          64.2782         2468.130719
# 313                   52          92.8138         2416.310937
# 314                  130          52.2255         2328.173019
# 315                   60          85.8766         2297.214841
# 316                   96          64.8404         1999.848860
#
#      ranking densidade
# 0                    1
# 1                    2
# 2                    3
# 3                    4
# 4                    5
# ..                 ...
# 312                313
# 313                314
# 314                315
# 315                316
# 316                317
#
# [317 rows x 8 columns]

# %%
# reorganizando as colunas da tabela

dados_densidade = dados_densidade[[
    'municipio', 'uf',
    'populacao', 'ranking populacao',
    'area urbana km²', 'ranking area urbana',
    'habitantes por km²', 'ranking densidade',
]]
dados_densidade
# Out:
#               municipio              uf  populacao  ranking populacao  \
# 0       Taboão da Serra       São Paulo     273542                101
# 1               Diadema       São Paulo     393237                 63
# 2           São Vicente       São Paulo     329911                 83
# 3    São João de Meriti  Rio de Janeiro     440962                 53
# 4             São Paulo       São Paulo   11451999                  1
# ..                  ...             ...        ...                ...
# 312             Atibaia       São Paulo     158647                188
# 313            Itaboraí  Rio de Janeiro     224267                139
# 314             Itatiba       São Paulo     121590                251
# 315              Maricá  Rio de Janeiro     197277                154
# 316            Araruama  Rio de Janeiro     129671                232
#
#      area urbana km²  ranking area urbana  habitantes por km²  \
# 0            18.6092                  516        14699.288524
# 1            27.5114                  311        14293.601925
# 2            26.2317                  334        12576.805926
# 3            35.2135                  221        12522.526872
# 4           914.5644                    1        12521.807103
# ..               ...                  ...                 ...
# 312          64.2782                  100         2468.130719
# 313          92.8138                   52         2416.310937
# 314          52.2255                  130         2328.173019
# 315          85.8766                   60         2297.214841
# 316          64.8404                   96         1999.848860
#
#      ranking densidade
# 0                    1
# 1                    2
# 2                    3
# 3                    4
# 4                    5
# ..                 ...
# 312                313
# 313                314
# 314                315
# 315                316
# 316                317
#
# [317 rows x 8 columns]

# %%
# não mantém os indices

dados_densidade.to_csv('densidade_populacao.csv', index=False)

# %%
dados_densidade.to_csv('densidade_teste.csv')
